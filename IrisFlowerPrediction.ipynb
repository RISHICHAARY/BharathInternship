# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
iris = datasets.load_iris()

X_Train , X_Test , Y_Train , Y_Test = train_test_split(iris.data[:,0],iris.target,test_size=0.2,random_state=42)

# %%
X_Train_Sq = X_Train * X_Train
X_Y_Train = X_Train * Y_Train

X_Train_Sum = np.sum(X_Train)
Y_Train_Sum = np.sum(Y_Train)
X_Y_Train_Sum = np.sum(X_Y_Train)
X_Train_Sq_Sum = np.sum(X_Train_Sq)

Intercept = ((Y_Train_Sum * X_Train_Sq_Sum)-(X_Train_Sum * X_Y_Train_Sum))/((len(X_Train)*X_Train_Sq_Sum)-((X_Train_Sum)**2))
Slope = ((len(X_Train)*X_Y_Train_Sum)-(X_Train_Sum * Y_Train_Sum))/((len(X_Train)*X_Train_Sq_Sum)-((X_Train_Sum)**2))

print(Intercept, Slope)
# Out:
# -3.3968026630371937 0.755438702574185

# %%
Predict = Intercept + (Slope * X_Test)

from sklearn.metrics import r2_score

print(Y_Test,Predict)
print(r2_score(Y_Test,Predict))

plt.plot(X_Test , Predict)
plt.scatter(X_Train , Y_Train)
plt.show
# Out:
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0] [1.21137342 0.90919794 2.42007535 1.13582955 1.74018051 0.68256633
#  0.83365407 1.81572438 1.28691729 0.98474181 1.5135489  0.22930311
#  0.7581102  0.30484698 0.45593472 1.36246116 1.5135489  0.83365407
#  0.90919794 1.43800503 0.15375924 1.21137342 0.38039085 1.43800503
#  2.57116309 1.66463664 1.66463664 1.74018051 0.22930311 0.22930311]
# 0.7167580265093714
# <function matplotlib.pyplot.show(close=None, block=None)>
